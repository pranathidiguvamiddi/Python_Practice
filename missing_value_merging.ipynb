# %%
import pandas as pd

# %%
data=pd.read_csv("E:\\data_sets\\general_data.csv")

# %%
data
# Out:
#    id first_name   last_name                         email  gender  \
# 0   1     Damian         NaN  darchdeckne0@dagondesign.com     NaN
# 1   2      Keith         NaN      kstrachan1@newyorker.com    Male
# 2   3        NaN     Lettley             alettley2@free.fr  Female
# 3   4     Lillis       Molan            lmolan3@drupal.org  Female
# 4   5        Bud  Kitchaside        bkitchaside4@google.ca    Male
# 5   6    Chilton       Dadge       cdadge5@themeforest.net    Male
# 6   7        NaN         NaN      zstillgoe6@indiegogo.com  Female
# 7   8     Moishe      Tommei        mtommei7@123-reg.co.uk    Male
# 8   9      Lanae    Georgiev            lgeorgiev8@wix.com  Female
# 9  10        Rem         NaN       rgeerling9@cbslocal.com    Male
#
#         ip_address
# 0     44.134.49.55
# 1  162.239.143.195
# 2    97.153.85.217
# 3   173.117.26.162
# 4     131.0.12.116
# 5              NaN
# 6    63.108.70.155
# 7    90.200.149.35
# 8    11.222.93.140
# 9              NaN

# %%
df=pd.DataFrame(data)

# %%
print(df)
# Out:
#    id first_name   last_name                         email  gender  \
# 0   1     Damian         NaN  darchdeckne0@dagondesign.com     NaN
# 1   2      Keith         NaN      kstrachan1@newyorker.com    Male
# 2   3        NaN     Lettley             alettley2@free.fr  Female
# 3   4     Lillis       Molan            lmolan3@drupal.org  Female
# 4   5        Bud  Kitchaside        bkitchaside4@google.ca    Male
# 5   6    Chilton       Dadge       cdadge5@themeforest.net    Male
# 6   7        NaN         NaN      zstillgoe6@indiegogo.com  Female
# 7   8     Moishe      Tommei        mtommei7@123-reg.co.uk    Male
# 8   9      Lanae    Georgiev            lgeorgiev8@wix.com  Female
# 9  10        Rem         NaN       rgeerling9@cbslocal.com    Male
#
#         ip_address
# 0     44.134.49.55
# 1  162.239.143.195
# 2    97.153.85.217
# 3   173.117.26.162
# 4     131.0.12.116
# 5              NaN
# 6    63.108.70.155
# 7    90.200.149.35
# 8    11.222.93.140
# 9              NaN

# %%
missing_value=df.isnull().sum()

# %%
missing_value
# Out:
# id            0
# first_name    2
# last_name     4
# email         0
# gender        1
# ip_address    2
# dtype: int64

# %%
df['first_name'].fillna('unknow',inplace=True)
df['last_name'].fillna('unknow',inplace=True)

# %%
df
# Out:
#    id first_name   last_name                         email  gender  \
# 0   1     Damian      unknow  darchdeckne0@dagondesign.com     NaN
# 1   2      Keith      unknow      kstrachan1@newyorker.com    Male
# 2   3     unknow     Lettley             alettley2@free.fr  Female
# 3   4     Lillis       Molan            lmolan3@drupal.org  Female
# 4   5        Bud  Kitchaside        bkitchaside4@google.ca    Male
# 5   6    Chilton       Dadge       cdadge5@themeforest.net    Male
# 6   7     unknow      unknow      zstillgoe6@indiegogo.com  Female
# 7   8     Moishe      Tommei        mtommei7@123-reg.co.uk    Male
# 8   9      Lanae    Georgiev            lgeorgiev8@wix.com  Female
# 9  10        Rem      unknow       rgeerling9@cbslocal.com    Male
#
#         ip_address
# 0     44.134.49.55
# 1  162.239.143.195
# 2    97.153.85.217
# 3   173.117.26.162
# 4     131.0.12.116
# 5              NaN
# 6    63.108.70.155
# 7    90.200.149.35
# 8    11.222.93.140
# 9              NaN

# %%
df['gender'].fillna('unkown',inplace=True)

# %%
df
# Out:
#    id first_name   last_name                         email  gender  \
# 0   1     Damian      unknow  darchdeckne0@dagondesign.com  unkown
# 1   2      Keith      unknow      kstrachan1@newyorker.com    Male
# 2   3     unknow     Lettley             alettley2@free.fr  Female
# 3   4     Lillis       Molan            lmolan3@drupal.org  Female
# 4   5        Bud  Kitchaside        bkitchaside4@google.ca    Male
# 5   6    Chilton       Dadge       cdadge5@themeforest.net    Male
# 6   7     unknow      unknow      zstillgoe6@indiegogo.com  Female
# 7   8     Moishe      Tommei        mtommei7@123-reg.co.uk    Male
# 8   9      Lanae    Georgiev            lgeorgiev8@wix.com  Female
# 9  10        Rem      unknow       rgeerling9@cbslocal.com    Male
#
#         ip_address
# 0     44.134.49.55
# 1  162.239.143.195
# 2    97.153.85.217
# 3   173.117.26.162
# 4     131.0.12.116
# 5              NaN
# 6    63.108.70.155
# 7    90.200.149.35
# 8    11.222.93.140
# 9              NaN

# %%
#reverse the data 
df_reverse=df.iloc[::-1,::-1]#.reset_index(drop=True)

# %%
df_reverse
# Out:
#         ip_address  gender                         email   last_name  \
# 9       Unknown IP    Male       rgeerling9@cbslocal.com      unknow
# 8    11.222.93.140  Female            lgeorgiev8@wix.com    Georgiev
# 7    90.200.149.35    Male        mtommei7@123-reg.co.uk      Tommei
# 6    63.108.70.155  Female      zstillgoe6@indiegogo.com      unknow
# 5       Unknown IP    Male       cdadge5@themeforest.net       Dadge
# 4     131.0.12.116    Male        bkitchaside4@google.ca  Kitchaside
# 3   173.117.26.162  Female            lmolan3@drupal.org       Molan
# 2    97.153.85.217  Female             alettley2@free.fr     Lettley
# 1  162.239.143.195    Male      kstrachan1@newyorker.com      unknow
# 0     44.134.49.55  unkown  darchdeckne0@dagondesign.com      unknow
#
#   first_name  id
# 9        Rem  10
# 8      Lanae   9
# 7     Moishe   8
# 6     unknow   7
# 5    Chilton   6
# 4        Bud   5
# 3     Lillis   4
# 2     unknow   3
# 1      Keith   2
# 0     Damian   1

# %%
"""
the difference between loc&iloc is 
loc is given to the row,colums we are given
and loc row & colums name s given as the indexindig order or slicing
iloc is the given row numbers and given colums name of the iloc
"""
# Out:
# '\nthe difference between loc&iloc is \nloc is given to the row,colums we are given\nand loc row & colums name s given as the indexindig order or slicing\niloc is the given row numbers and given colums name of the iloc\n'

# %%
#drop missing values
df_drop_missing_rows=df.dropna()

# %%
df
# Out:
#    id first_name   last_name                         email  gender  \
# 0   1     Damian      unknow  darchdeckne0@dagondesign.com  unkown
# 1   2      Keith      unknow      kstrachan1@newyorker.com    Male
# 2   3     unknow     Lettley             alettley2@free.fr  Female
# 3   4     Lillis       Molan            lmolan3@drupal.org  Female
# 4   5        Bud  Kitchaside        bkitchaside4@google.ca    Male
# 5   6    Chilton       Dadge       cdadge5@themeforest.net    Male
# 6   7     unknow      unknow      zstillgoe6@indiegogo.com  Female
# 7   8     Moishe      Tommei        mtommei7@123-reg.co.uk    Male
# 8   9      Lanae    Georgiev            lgeorgiev8@wix.com  Female
# 9  10        Rem      unknow       rgeerling9@cbslocal.com    Male
#
#         ip_address
# 0     44.134.49.55
# 1  162.239.143.195
# 2    97.153.85.217
# 3   173.117.26.162
# 4     131.0.12.116
# 5              NaN
# 6    63.108.70.155
# 7    90.200.149.35
# 8    11.222.93.140
# 9              NaN

# %%
df_drop_missing_column=df.dropna(axis=1)

# %%
df_drop_missing_column
# Out:
#    id first_name   last_name                         email  gender
# 0   1     Damian      unknow  darchdeckne0@dagondesign.com  unkown
# 1   2      Keith      unknow      kstrachan1@newyorker.com    Male
# 2   3     unknow     Lettley             alettley2@free.fr  Female
# 3   4     Lillis       Molan            lmolan3@drupal.org  Female
# 4   5        Bud  Kitchaside        bkitchaside4@google.ca    Male
# 5   6    Chilton       Dadge       cdadge5@themeforest.net    Male
# 6   7     unknow      unknow      zstillgoe6@indiegogo.com  Female
# 7   8     Moishe      Tommei        mtommei7@123-reg.co.uk    Male
# 8   9      Lanae    Georgiev            lgeorgiev8@wix.com  Female
# 9  10        Rem      unknow       rgeerling9@cbslocal.com    Male

# %%
df_drop_missing_rows
# Out:
#    id first_name   last_name                         email  gender  \
# 0   1     Damian      unknow  darchdeckne0@dagondesign.com  unkown
# 1   2      Keith      unknow      kstrachan1@newyorker.com    Male
# 2   3     unknow     Lettley             alettley2@free.fr  Female
# 3   4     Lillis       Molan            lmolan3@drupal.org  Female
# 4   5        Bud  Kitchaside        bkitchaside4@google.ca    Male
# 6   7     unknow      unknow      zstillgoe6@indiegogo.com  Female
# 7   8     Moishe      Tommei        mtommei7@123-reg.co.uk    Male
# 8   9      Lanae    Georgiev            lgeorgiev8@wix.com  Female
#
#         ip_address
# 0     44.134.49.55
# 1  162.239.143.195
# 2    97.153.85.217
# 3   173.117.26.162
# 4     131.0.12.116
# 6    63.108.70.155
# 7    90.200.149.35
# 8    11.222.93.140

# %%
df.fillna({
    'first_name': 'Unknown',
    'last_name': 'Unknown',
    'gender': 'Not Specified',
    'ip_address': 'Unknown IP'
}, inplace=True)

# %%
df
# Out:
#    id first_name   last_name                         email  gender  \
# 0   1     Damian      unknow  darchdeckne0@dagondesign.com  unkown
# 1   2      Keith      unknow      kstrachan1@newyorker.com    Male
# 2   3     unknow     Lettley             alettley2@free.fr  Female
# 3   4     Lillis       Molan            lmolan3@drupal.org  Female
# 4   5        Bud  Kitchaside        bkitchaside4@google.ca    Male
# 5   6    Chilton       Dadge       cdadge5@themeforest.net    Male
# 6   7     unknow      unknow      zstillgoe6@indiegogo.com  Female
# 7   8     Moishe      Tommei        mtommei7@123-reg.co.uk    Male
# 8   9      Lanae    Georgiev            lgeorgiev8@wix.com  Female
# 9  10        Rem      unknow       rgeerling9@cbslocal.com    Male
#
#         ip_address
# 0     44.134.49.55
# 1  162.239.143.195
# 2    97.153.85.217
# 3   173.117.26.162
# 4     131.0.12.116
# 5       Unknown IP
# 6    63.108.70.155
# 7    90.200.149.35
# 8    11.222.93.140
# 9       Unknown IP

# %%
df1 = pd.DataFrame({
    'id': [1, 2, 2, 3],
    'type': ['A', 'A', 'B', 'A'],
    'value': [10, 20, 30, 40]
})

# %%
df1
# Out:
#    id type  value
# 0   1    A     10
# 1   2    A     20
# 2   2    B     30
# 3   3    A     40

# %%
df2 = pd.DataFrame({
    'id': [2, 2, 4],
    'type': ['A', 'B', 'A'],
    'description': ['Desc1', 'Desc2', 'Desc3']
})

# %%
df2
# Out:
#    id type description
# 0   2    A       Desc1
# 1   2    B       Desc2
# 2   4    A       Desc3

# %%
# Merge on multiple columns
multi_merged = pd.merge(df1, df2, on=['id', 'type'], how='inner')

# %%
multi_merged
# Out:
#    id type  value description
# 0   2    A     20       Desc1
# 1   2    B     30       Desc2

# %%
df5 = pd.DataFrame({
    'value1': [10, 20, 30],
    'value2': [100, 200, 300]
}, index=['a', 'b', 'c'])

# %%
df5
# Out:
#    value1  value2
# a      10     100
# b      20     200
# c      30     300

# %%
df6 = pd.DataFrame({
    'value3': [15, 25],
    'value4': [150, 250]
}, index=['b', 'c'])

# %%
df6
# Out:
#    value3  value4
# b      15     150
# c      25     250

# %%
index_merged = pd.merge(df5, df6, left_index=True, right_index=True, how='inner')

# %%
index_merged
# Out:
#    value1  value2  value3  value4
# b      20     200      15     150
# c      30     300      25     250
