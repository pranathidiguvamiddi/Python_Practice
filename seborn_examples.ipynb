# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Generate a random correlation matrix
data = np.random.rand(10, 10)

# Create heatmap
sns.heatmap(data, annot=True, cmap='coolwarm')

# Add title
plt.title('Heatmap of Random Data')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load a built-in dataset
tips = sns.load_dataset('tips')

# Display the first few rows of the dataset
print(tips.head())
# Set the style of the plot
sns.set_style('darkgrid')
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Set the style of the plot
sns.set_style('darkgrid')

# %%
# Bar plot
sns.barplot(x='day', y='total_bill', data=tips)

# Show the plot
plt.show()
# Out:
# C:\Users\User\anaconda3  1\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# Count plot
sns.countplot(x='day', data=tips)

# Show the plot
plt.show()
# Out:
# C:\Users\User\anaconda3  1\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# Scatter plot
sns.scatterplot(x='total_bill', y='tip', data=tips)

# Show the plot
plt.show()

# %%
# Histogram
sns.histplot(tips['total_bill'], bins=20, kde=True)

# Show the plot
plt.show()
# Out:
# C:\Users\User\anaconda3  1\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Bar plot with customization
sns.barplot(x='day', y='total_bill', data=tips)

# Add labels and title
plt.xlabel('Day of the Week')
plt.ylabel('Total Bill')
plt.title('Total Bill by Day')

# Show the plot
plt.show()
# Out:
# C:\Users\User\anaconda3  1\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# Bar plot (mean aggregation by default)
sns.barplot(x='day', y='total_bill', data=tips)

# Box plot
sns.boxplot(x='day', y='total_bill', data=tips)

# Show the plots
plt.show()
# Out:
# C:\Users\User\anaconda3  1\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\User\anaconda3  1\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# FacetGrid for subplots
g = sns.FacetGrid(tips, col='sex', row='smoker')
g.map(sns.scatterplot, 'total_bill', 'tip')

# Show the plots
plt.show()

# %%
# Set a color palette
sns.set_palette('pastel')

# Create a bar plot with a color palette
sns.barplot(x='day', y='total_bill', data=tips)

# Show the plot
plt.show()
# Out:
# C:\Users\User\anaconda3  1\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# Save plot to a file
sns.barplot(x='day', y='total_bill', data=tips)
plt.savefig('barplot.png')

# Show the plot
plt.show()
# Out:
# C:\Users\User\anaconda3  1\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
import seaborn as sns
sns.distplot(tips['total_bill'],kde=False)
plt.show()

# %%
import seaborn as sns
sns.distplot(tips['total_bill'],kde=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 import seaborn as sns
# ----> 2 sns.distplot(tips['total_bill'],kde=False)
#       3 plt.show()
#
# NameError: name 'tips' is not defined
